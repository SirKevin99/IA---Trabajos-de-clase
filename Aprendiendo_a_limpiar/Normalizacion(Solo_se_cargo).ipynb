# %%
import pandas as pd
df = pd.read_csv('dataset2.csv', encoding='latin1', index_col=0)

# %%
df.head(20)
# Out:
#                   Nombre y Apellido  MatemÃ¡tica  FÃ­sica  ProgramaciÃ³n  \
# Nro de documento
# 10234567                Juan PÃ©rez          5.0      5.0            5.0
# 11890123             MarÃ­a GarcÃ­a          2.0      2.0            3.0
# 12456789              Carlos LÃ³pez          5.0      4.0            5.0
# 13321654             Ana RodrÃ­guez          1.0      2.0            2.0
# 14789012             Luis MartÃ­nez          3.0      3.0            4.0
# 15147258               Elena GÃ³mez          5.0      5.0            5.0
# 16963852               Diego Torres          2.0      1.0            3.0
# 17159357              SofÃ­a Castro          4.0      4.0            3.0
# 18753159                Javier Ruiz          3.0      2.0            4.0
# 19456123             LucÃ­a Morales          4.0      5.0            4.0
# 10234567                 JUAN PEREZ          5.0      5.0            5.0
# 20567890             marcos benitez          3.0      NaN            2.0
# ...

# %%
print(df.info())
print(df.head)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, 10234567 to 58765432
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Nombre y Apellido     50 non-null     object
#  1   MatemÃ¡tica           49 non-null     float64
#  2   FÃ­sica               49 non-null     float64
#  3   ProgramaciÃ³n         49 non-null     float64
#  4   Lengua                50 non-null     int64
#  5   EstadÃ­stica          49 non-null     float64
#  6   Historia y Geografia  49 non-null     float64
#  7   Castellano            49 non-null     float64
#  8   Educacion etica       50 non-null     int64
#  9   Geometria             50 non-null     int64
# dtypes: float64(6), int64(3), object(1)
# memory usage: 4.3+ KB
# None
# <bound method NDFrame.head of                   Nombre y Apellido  MatemÃ¡tica  FÃ­sica  ProgramaciÃ³n  \
# Nro de documento
# ...

# %%
print(df.head)
# Out:
# <bound method NDFrame.head of                   Nombre y Apellido  MatemÃ¡tica  FÃ­sica  ProgramaciÃ³n  \
# Nro de documento
# 10234567                Juan PÃ©rez          5.0      5.0            5.0
# 11890123             MarÃ­a GarcÃ­a          2.0      2.0            3.0
# 12456789              Carlos LÃ³pez          5.0      4.0            5.0
# 13321654             Ana RodrÃ­guez          1.0      2.0            2.0
# 14789012             Luis MartÃ­nez          3.0      3.0            4.0
# 15147258               Elena GÃ³mez          5.0      5.0            5.0
# 16963852               Diego Torres          2.0      1.0            3.0
# 17159357              SofÃ­a Castro          4.0      4.0            3.0
# 18753159                Javier Ruiz          3.0      2.0            4.0
# 19456123             LucÃ­a Morales          4.0      5.0            4.0
# 10234567                 JUAN PEREZ          5.0      5.0            5.0
# ...

# %%
# Out:
#    Nro de documento Nombre y Apellido  MatemÃ¡tica  FÃ­sica  ProgramaciÃ³n  \
# 0          10234567       Juan PÃ©rez          5.0      5.0            5.0
# 1          11890123    MarÃ­a GarcÃ­a          2.0      2.0            3.0
# 2          12456789     Carlos LÃ³pez          5.0      4.0            5.0
# 3          13321654    Ana RodrÃ­guez          1.0      2.0            2.0
# 4          14789012    Luis MartÃ­nez          3.0      3.0            4.0
#
#    Lengua  EstadÃ­stica  Historia y Geografia  Castellano  Educacion etica  \
# 0       5           5.0                   5.0         5.0                5
# 1       4           2.0                   4.0         5.0                3
# 2       3           4.0                   4.0         3.0                4
# 3       3           2.0                   3.0         3.0                2
# 4       4           5.0                   5.0         4.0                4
#
#    Geometria
# 0          5
# 1          2
# 2          5
# ...

# %%
# Esta forma es segura de correr muchas veces
cols_a_borrar = ['Unnamed: 0']

# Solo borra si la columna realmente existe en el dataframe actual
df = df.drop(columns=[c for c in cols_a_borrar if c in df.columns])

# %%
# Esto te mostrará los valores únicos en la columna 'Matematica'
print(df['MatemÃ¡tica'].unique())
# Out:
# [ 5.  2.  1.  3.  4. nan]
